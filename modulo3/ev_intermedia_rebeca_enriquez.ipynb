# %% [markdown]
# # Evaluacion intermedia

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None) 
# Para ver los datos Float en formato con decimales y nos quita la notacion cientifica
# pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df = pd.read_csv("Spotify_Youtube.csv", index_col=0)

# %% [markdown]
# ## Exploración del conjunto de datos:

# %%
df.head()
# Out:
#      Artist                                        Url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single
# ...

# %%
df.tail()
# Out:
#             Artist                                        Url_spotify  \
# 20713  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20716  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20717  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
#
#                                 Track                           Album  \
# 20713            JUST DANCE HARDSTYLE            JUST DANCE HARDSTYLE
# 20714  SET FIRE TO THE RAIN HARDSTYLE  SET FIRE TO THE RAIN HARDSTYLE
# 20715       OUTSIDE HARDSTYLE SPED UP       OUTSIDE HARDSTYLE SPED UP
# 20716             ONLY GIRL HARDSTYLE             ONLY GIRL HARDSTYLE
# 20717              MISS YOU HARDSTYLE              MISS YOU HARDSTYLE
#
#       Album_type                                   Uri Danceability Energy  \
# ...

# %%
df.sample(10)
# Out:
#                   Artist                                        Url_spotify  \
# 7638   Killswitch Engage  https://open.spotify.com/artist/37394IP6uhnjIp...
# 15965       Travis Scott  https://open.spotify.com/artist/0Y5tJX1MQlPlqi...
# 2728      José Feliciano  https://open.spotify.com/artist/7K78lVZ8XzkjfR...
# 5984         Ilaiyaraaja  https://open.spotify.com/artist/3m49WVMU4zCkaV...
# 18202       Bryant Myers  https://open.spotify.com/artist/6w9ToX5slZ4uId...
# 15343          blackbear  https://open.spotify.com/artist/2cFrymmkijnjDg...
# 10835        Kany García  https://open.spotify.com/artist/69UypehHabb68u...
# 5240                 D12  https://open.spotify.com/artist/5Qi4Bb7a8C0a00...
# 2694     Andrés Calamaro  https://open.spotify.com/artist/3tAICgiSR5PfYY...
# 16259             AURORA  https://open.spotify.com/artist/1WgXqy2Dd70QQO...
#
#                                       Track  \
# 7638                             Holy Diver
# ...

# %%
df.shape
# Out:
# (20718, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20718 entries, 0 to 20717
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist            20718 non-null  object
#  1   Url_spotify       20718 non-null  object
#  2   Track             20718 non-null  object
#  3   Album             20718 non-null  object
#  4   Album_type        20718 non-null  object
#  5   Uri               20718 non-null  object
#  6   Danceability      20716 non-null  object
#  7   Energy            20716 non-null  object
#  8   Key               20716 non-null  object
#  9   Loudness          20716 non-null  object
#  10  Speechiness       20716 non-null  object
#  11  Acousticness      20716 non-null  object
#  12  Instrumentalness  20716 non-null  object
#  13  Liveness          20716 non-null  float64
#  14  Valence           20716 non-null  float64
#  15  Tempo             20716 non-null  float64
# ...

# %%
round(df.isnull().sum()/df.shape[0]*100,2)
# Out:
# artist              0.00
# url_spotify         0.00
# track               0.00
# album               0.00
# album_type          0.00
# uri                 0.00
# danceability        0.01
# energy              0.01
# key                 0.01
# loudness            0.01
# speechiness         0.01
# acousticness        0.01
# instrumentalness    0.01
# liveness            0.01
# valence             0.01
# tempo               0.01
# duration_ms         0.01
# url_youtube         2.27
# title               2.27
# channel             2.27
# views               2.27
# likes               2.61
# comments            2.75
# description         4.23
# licensed            2.27
# official_video      2.27
# stream              2.78
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#                count          mean           std         min           25%  \
# Liveness     20716.0  1.935210e-01  1.685309e-01      0.0145  9.410000e-02
# Valence      20716.0  5.298533e-01  2.454408e-01      0.0000  3.390000e-01
# Tempo        20716.0  1.206383e+02  2.957902e+01      0.0000  9.700200e+01
# Duration_ms  20716.0  2.247176e+05  1.247905e+05  30985.0000  1.800095e+05
# Views        20248.0  9.393782e+07  2.746443e+08      0.0000  1.826002e+06
# Likes        20177.0  6.633411e+05  1.789324e+06      0.0000  2.158100e+04
# Comments     20149.0  2.751899e+04  1.932347e+05      0.0000  5.090000e+02
# Stream       20142.0  1.359422e+08  2.441321e+08   6574.0000  1.767486e+07
#
#                       50%           75%           max
# Liveness     1.250000e-01  2.370000e-01  1.000000e+00
# Valence      5.370000e-01  7.262500e-01  9.930000e-01
# Tempo        1.199650e+02  1.399350e+02  2.433720e+02
# Duration_ms  2.132845e+05  2.524430e+05  4.676058e+06
# ...

# %%
df.describe(include = "object").T
# Out:
#                   count unique  \
# Artist            20718   2079
# Url_spotify       20718   2079
# Track             20718  17841
# Album             20718  11937
# Album_type        20718      3
# Uri               20718  18862
# Danceability      20716    898
# Energy            20716   1268
# Key               20716     12
# Loudness          20716   9417
# Speechiness       20716   1303
# Acousticness      20716   3138
# Instrumentalness  20716   4012
# Url_youtube       20248  18154
# Title             20248  18146
# Channel           20248   6714
# Description       19842  17395
# Licensed          20248      2
# Official_video    20248      2
#
#                                                                 top   freq
# Artist                                                     Gorillaz     10
# Url_spotify       https://open.spotify.com/artist/3AA28KZvwAUcZu...     10
# Track                     El Ultimo Adiós - Varios Artistas Version     24
# ...

# %% [markdown]
# ## Preparación de los datos:

# %% [markdown]
# - Los nombres de las columnas empiezan con mayúsculas, pon todos los nombres de las columnas en minúsculas.

# %%
df.columns
# Out:
# Index(['Artist', 'Url_spotify', 'Track', 'Album', 'Album_type', 'Uri',
#        'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'Official_video', 'Stream'],
#       dtype='object')

# %%
nombres_columnas = {columna : columna.lower() for columna in df.columns}
df.rename(columns=nombres_columnas, inplace=True)
df.columns
# Out:
# Index(['artist', 'url_spotify', 'track', 'album', 'album_type', 'uri',
#        'danceability', 'energy', 'key', 'loudness', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'url_youtube', 'title', 'channel', 'views', 'likes',
#        'comments', 'description', 'licensed', 'official_video', 'stream'],
#       dtype='object')

# %% [markdown]
# - Haciendo el análisis exploratorio te deberías haber dado cuenta de que algunas de las variables (`danceability`, `energy`, `key`, `loudness`, `speechiness`, `acousticness`, `instrumentalness`) no son del tipo que deberían. Esto es debido a que los decimales están establecidos como comas y no con puntos. Crea una función que nos permita cambiar esas comas por puntos para que los datos tengan el tipo correcto.
#
# - Después de haber hecho los cambios, chequea los tipos de datos. ¿Son ya del tipo correcto? En caso de que no, crea otra función o modifica la anterior para que sean de tipo *float*.

# %%
def cambio_signos_puntuacion(elemento):

    try:     
        return float(elemento.replace(",","."))
    
    except:
        return np.nan

# %%
columnas_cambios = ["danceability", "energy", "key", "loudness", "speechiness", "acousticness", "instrumentalness"]

# %%
for columna in columnas_cambios:
    df[columna] = df[columna].apply(cambio_signos_puntuacion)

# %%
for columna in columnas_cambios:
    print(f"la columnas {columna.upper()} es de tipo:{df[columna].dtype}")

# Podemos hacer df.dtypes y ahorrarnos el bucle
# Out:
# la columnas DANCEABILITY es de tipo:float64
# la columnas ENERGY es de tipo:float64
# la columnas KEY es de tipo:float64
# la columnas LOUDNESS es de tipo:float64
# la columnas SPEECHINESS es de tipo:float64
# la columnas ACOUSTICNESS es de tipo:float64
# la columnas INSTRUMENTALNESS es de tipo:float64

# %% [markdown]
# - Hay algunas canciones cuyo título está en mayúsulas. Crea una función para que todos los títulos estén en minúscula. Haz lo mismo para las columnas de "title" y "album".

# %%
columnas_cambios_miniscula =["track", "title", "album"]

# %%
for columna in columnas_cambios_miniscula:
    df[columna] = df[columna].str.lower()

# %% [markdown]
# Lo podemos hacer sobre el DF como se puede ver arriba o haciendo una funcion y aplicando a cada celda con apply

# %%
def cambio_minusculas(celda):
    try:
        return celda.lower()
    except:
        return None

# %%
for columna in columnas_cambios_miniscula:
    df[columna] = df[columna].apply(cambio_minusculas)

# %%
# Para hacerlo con una lambda
for col in columnas_cambios_miniscula:
    df[col] = df[col].apply(lambda dato: dato.lower() if type(dato)== str else dato)

# %% [markdown]
# - Algunos de los artistas tienen símbolos raros, en concreto el símbolo `$`. Crea una función que los reemplaze pos "s".

# %%
# hacer la comprobacion
# Sin regex
df[df["artist"].str.contains("$", regex = False)]["artist"].unique()

# Con regex
df[df["artist"].str.contains("\$", regex = True)]["artist"].unique()

# %%
columnas_cambios_simbolo = ["artist"]

# %%
def cambio_simbolo(celda):
    return celda.replace("$","s")

# %%
for columna in columnas_cambios_simbolo:
    df[columna] = df[columna].apply(cambio_simbolo)

# %%
# Lo podemos hacer con una lambda
df["artist"] = df["artist"].apply(lambda dato: dato.replace("$","S"))

# Comprobamos que nos ha cambiado los datos, nuestro objetivo es que la lista que devuelva este vacia
df[df["artist"].str.contains("$", regex = False)]["artist"].unique()
# Out:
# array([], dtype=object)

# %% [markdown]
# ## Filtrado de datos:

# %% [markdown]
# - ¿Cuáles son los valores únicos de la columna "album_type"? Crea tres *dataframes* diferentes, uno para cada tipo de "album_type". ¿Cuántas canciones tenemos en cada tipo?

# %%
df["album_type"].unique()
# Out:
# array(['album', 'single', 'compilation'], dtype=object)

# %%
df.groupby("album_type")["album_type"].count().reset_index(name="Recuento")

#Esto lo podemos hacer con un value counts de maneramas sencilla
#df["album_type"].value_counts()
# Out:
#     album_type  Recuento
# 0        album     14926
# 1  compilation       788
# 2       single      5004

# %%
# Creacion de 3 DF por tipo de album

df_single = df[df["album_type"] == "single"]
df_comp = df[df["album_type"] == "compilation"]
df_album = df[df["album_type"] == "album"]

# %% [markdown]
# - Usando el *dataframe* de los albumes que hemos creado en el ejercicio anterior. ¿Cuál es la media y la desviación estándar de "danceability", "acousticness" y "speechiness" de cada artista?. Muesrtra los resultados en tres dataframes diferentes, uno para cada métrica ("danceability", "acousticness" y "speechiness"). Ordena los resultados de mayor a menor en base a la media.

# %% [markdown]
# - **BONUS** Haced lo mismo para los datos de tipo "single".

# %%
metrica = ["danceability", "acousticness","speechiness"]
categorias = {"album" : df_album, "single": df_single}

# %%
for n, d in categorias.items():
    for i in metrica:
        print(f"Dataframe {n}, metrica {i}")
        display(d.groupby("artist")[i].agg(["mean","std"]).reset_index().sort_values(by= "mean", ascending= False))
        print("________________" )
# Out:
# Dataframe album, metrica danceability
#                       artist      mean       std
# 1003                   Latto  0.922333  0.014503
# 1261                   Murda  0.911500  0.030406
# 848                    Jon Z  0.886000  0.015556
# 204                 Blueface  0.885000  0.043782
# 887                Jung Kook  0.881000       NaN
# ...                      ...       ...       ...
# 1661        Stephen Cleobury  0.142067  0.042212
# 1341            Ocean Sounds  0.137980  0.063706
# 1342   Ocean Waves For Sleep  0.133533  0.061768
# 1897  White Noise for Babies  0.090262  0.163895
# 1896  White Noise Baby Sleep  0.066270  0.071434
#
# [1989 rows x 3 columns]
# ________________
# Dataframe album, metrica acousticness
#                    artist      mean       std
# 351        Claude Debussy  0.993714  0.001380
# 1509      Robert Schumann  0.993444  0.004902
# 601        Franz Schubert  0.989500  0.005237
# 506          Edvard Grieg  0.989500  0.007863
# ...

# %% [markdown]
# - Se quiere estudiar si existe una relación entre la cantidad de visitas que reciben los videos de música de un artista en una plataforma de streaming y la cantidad de likes que estos videos obtienen. Por lo tanto, querremos contestar a la siguiente pregunta: ¿Son aquellos artistas que tienen más visitas los que más likes tienen? Para solucionar este ejercicio deberéis:
#
#         - Agrupa por artista y calcular la media de visitas y de likes.
#
#         - Quedate con los 10 artistas que más visitas han tenido.
#
#         - Quedate con los 10 artistas que más likes han tenido.

# %%
artista_like = df.groupby("artist")[["views","likes"]].mean()

#Tambien lo podemos hacer:
# artista_like = df.groupby("artist").agg({"views":"mean", 'likes':'mean'}).reset_index()

artista_like
# Out:
#                          views      likes
# artist
# (G)I-DLE           175495394.1  2446296.3
# *NSYNC             102783286.2   423342.3
# 070 Shake            9609935.9   201300.5
# 112                 21913445.9   150914.1
# 11:11 Music Group    1267282.4    17970.1
# ...                        ...        ...
# will.i.am          283132016.6  1386447.1
# Ángela Aguilar     138529529.1  1029475.7
# Ñejo                62668082.4   434891.0
# Ñengo Flow          81272631.5   676034.0
# Øneheart             3462331.0   127216.7
#
# [2079 rows x 2 columns]

# %%
artista_10views = df.groupby("artist").agg({"views":"mean", 'likes':'mean'}).reset_index().sort_values(by= "views", ascending= False)
artista_10views.head(10)
# Out:
#                        artist         views      likes
# 524                Ed Sheeran  1.546021e+09  8354331.9
# 372                 CoComelon  1.460167e+09  4171391.3
# 953                Katy Perry  1.312063e+09  6306709.0
# 331              Charlie Puth  1.216759e+09  8633692.5
# 1147               Luis Fonsi  1.162811e+09  6690848.9
# 925             Justin Bieber  1.099106e+09  7858434.8
# 420              Daddy Yankee  1.087193e+09  6551817.1
# 265                Bruno Mars  1.024092e+09  5961614.6
# 1182  Macklemore & Ryan Lewis  1.012206e+09  6604141.0
# 379                  Coldplay  9.997278e+08  6315789.5

# %%
artista_10_likes = df.groupby("artist").agg({"views":"mean", 'likes':'mean'}).reset_index().sort_values(by= "likes", ascending= False)
artista_10_likes.head(10)
# Out:
#                artist         views       likes
# 151               BTS  5.607867e+08  13940380.8
# 149         BLACKPINK  9.392962e+08  13230250.5
# 331      Charlie Puth  1.216759e+09   8633692.5
# 524        Ed Sheeran  1.546021e+09   8354331.9
# 925     Justin Bieber  1.099106e+09   7858434.8
# 200     Billie Eilish  4.821569e+08   7333853.7
# 775   Imagine Dragons  9.093785e+08   7227447.7
# 55        Alan Walker  7.256847e+08   6797770.2
# 416          DJ Snake  9.180268e+08   6777583.1
# 1147       Luis Fonsi  1.162811e+09   6690848.9

# %%
datos_single = df[df["album_type"] == "single"].groupby("album_type").agg({'views': 'count', 'likes': 'count'}).reset_index()

datos_single
# Out:
#   album_type  views  likes
# 0     single   4860   4852

# %%
datos_single= df.groupby("artist").agg({"views":"mean", 'likes':'mean'}).reset_index()

# %% [markdown]
# - Ahora queremos analizar la colaboración entre artistas en la industria musical, se tienen datos de las colaboraciones realizadas en los últimos años. Se desea conocer cuáles son los artistas que han colaborado en mayor cantidad de canciones y generar un *ranking* con los diez primeros. ¿Qué artistas con los que más colaboraciones tienen? Para esto tendréis que:
#
#         - Filtra los datos para quedarte solo con aquellos datos donde en la columna "track" tengamos "feat".
#
#         - Cuenta cuantas canciones tiene cada artista utilizando el *dataframe* generado en el paso anterior.
#
#
#         - Debes contestar a las siguientes preguntas:
#
#             - ¿Cuáles son los diez artistas que más han colaborado  según los datos que tenemos?
#
#             - ¿Cuál es el número de canciones en los que ha colaborado el artista que ocupa el primer lugar en el *ranking*?
#
#             - ¿Cuál es el artista que ocupa el décimo lugar en el *ranking* y en cuántas canciones ha colaborado?

# %%
df.head()
# Out:
#      artist                                        url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            track  \
# 0                                 feel good inc.
# 1                                rhinestone eyes
# 2  new gold (feat. tame impala and bootie brown)
# 3                             on melancholy hill
# 4                                 clint eastwood
#
#                                            album album_type  \
# 0                                     demon days      album
# 1                                  plastic beach      album
# 2  new gold (feat. tame impala and bootie brown)     single
# ...

# %%
condicion = df["track"].str.contains("\\bfeat\\b", case=True, na=False, regex=True)

# %%
df_track = df.loc[condicion]

# %%
df_track.head()
# Out:
#       artist                                        url_spotify  \
# 2   Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 6   Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 7   Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 8   Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 27   50 Cent  https://open.spotify.com/artist/3q7HBObVc0L8jN...
#
#                                                 track  \
# 2       new gold (feat. tame impala and bootie brown)
# 6   new gold (feat. tame impala and bootie brown) ...
# 7                  she's my collar (feat. kali uchis)
# 8                   cracker island (feat. thundercat)
# 27                 is this love ('09) (feat. 50 cent)
#
#                                                 album album_type  \
# 2       new gold (feat. tame impala and bootie brown)     single
# 6   new gold (feat. tame impala and bootie brown) ...     single
# ...

# %%
canciones_por_artista = df_track.groupby("artist")["track"].count().reset_index().sort_values(by = "track", ascending=False)
canciones_por_artista
# Out:
#              artist  track
# 401      Macklemore     10
# 61    Bibi und Tina     10
# 306         Juicy J     10
# 641   Ty Dolla sign      9
# 661    Wu-Tang Clan      9
# ..              ...    ...
# 329   Kenny Loggins      1
# 326  Kendrick Lamar      1
# 324   Kelly Rowland      1
# 320     Kavita Seth      1
# 694      Ñengo Flow      1
#
# [695 rows x 2 columns]

# %%
df_track.columns
# Out:
# Index(['artist', 'url_spotify', 'track', 'album', 'album_type', 'uri',
#        'danceability', 'energy', 'key', 'loudness', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'url_youtube', 'title', 'channel', 'views', 'likes',
#        'comments', 'description', 'licensed', 'official_video', 'stream'],
#       dtype='object')

# %%
artistas_colaboraciones_top10 = df_track.groupby("artist")["track"].count().reset_index().sort_values(by = "track", ascending=False)
artistas_colaboraciones_top10.head(10)
# Out:
#             artist  track
# 401     Macklemore     10
# 61   Bibi und Tina     10
# 306        Juicy J     10
# 641  Ty Dolla sign      9
# 661   Wu-Tang Clan      9
# 137      DJ Khaled      9
# 514        Popcaan      8
# 660         Wizkid      8
# 652           Wale      8
# 416    Mark Ronson      8

# %%
artistas_colaboraciones_top10.head(1)
# Out:
#          artist  track
# 401  Macklemore     10

# %%
artista_posicion_1 = artistas_colaboraciones_top10.iloc[0]
artista_posicion_10 = artistas_colaboraciones_top10.iloc[9]

print(f"Artista en la posición 1: \n",artista_posicion_1)
print("_________________________________")
print(f"Artista en la posición 10:\n",artista_posicion_10)
# Out:
# Artista en la posición 1:
#  artist    Macklemore
# track             10
# Name: 401, dtype: object
# _________________________________
# Artista en la posición 10:
#  artist    Mark Ronson
# track               8
# Name: 416, dtype: object
